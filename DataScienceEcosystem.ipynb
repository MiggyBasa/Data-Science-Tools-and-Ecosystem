# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Data Science Tools and Ecosystem<h1>

# %% [markdown]
# ![image.png](attachment:bfb74b74-1711-4589-8cbe-41fe7fc44d89.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](attachment:ca576279-0852-4096-8be3-e2e287ffb3bb.png)

# %% [markdown]
# __Objectives:__
# *C++
# *Java
# *Python
# *Scala

# %% [markdown]
# ![image.png](attachment:4e581b7f-0bc8-4a57-a57b-a1af807b4806.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Scala
# 2. Java
# 3. Julia

# %% [markdown]
# ![image.png](attachment:cf6beb86-700b-468c-b98c-3021145aea01.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. Tensorflow
# 2. PyTorch
# 3. Keras

# %% [markdown]
# ![image.png](attachment:d46ea76e-bf11-48ae-8a36-a4f8a983f415.png)

# %% [markdown]
# | Data Science Tools |
# :--------------------:
# |    Pixie Dust      |
# |       Hue          |
# |      Kibana        |

# %% [markdown]
# ![image.png](attachment:e3e691aa-3ee2-4177-b7f5-1b9c1e3a4cd7.png)

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python<h3>

# %% [markdown]
# ![image.png](attachment:979f1e41-094b-415e-b1c9-30ef0bbe9175.png)

# %%
(3*4)+5

# %% [markdown]
# ![image.png](attachment:3536ae66-c850-41ae-b9f9-6f75600a4265.png)

# %%
min=int(input("200"))
h=min//60
m=min%60
print("Hours=",h)
print("Minutes=",m)

# %% [markdown]
# ![image.png](attachment:3a1e7ac7-8358-4744-a771-453229d9ef8f.png)

# %% [markdown]
# <h2>Author<h2>
# Anthony Miguel Basa

# %% [markdown]
# ![image.png](attachment:da919308-464c-404c-ab43-53e426845fd3.png)
